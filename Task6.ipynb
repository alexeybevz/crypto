# %% [markdown]
# ### Задание 6. Расшифруйте данные зашифрованные XOR'ом с повторяющимся ключом.

# %%
for file in files:
    with open('.\Данные\\'+ file, 'r') as f:
        input_data = f.read()
        input_data = input_data.replace('\n', '')
    print(input_data)
# Out:
# ...
# ...
